# %%
#1

bilangan1 = int(input("Masukkan angka: "))
if bilangan1 % 2 == 0:
  print(f"Angka {bilangan1} adalah bilangan genap")
else:
  print(f"Angka {bilangan1} adalah bilangan ganjil")
# Out:
# Masukkan angka: 68
# Angka 68 adalah bilangan genap

# %%
#2
n = int(input("Masukkan angka: "))

a, b = 0, 1
count = 0

if n <= 0:
    print("Masukkan bilangan bulat positif.")
elif n == 1:
    print("Deret Fibonacci hingga suku ke-", n, ":", a)
# Out:
# Masukkan angka: 377

# %%
#4

for x in range(0,len(matrix)):
  for y in range(0,len(matrix[0])):
    print(matrix[x][y], end=' '),
  print
# Out:
# 5 0 2 6

# %% [markdown]
# Image Segmentation

# %%
import matplotlib.pyplot as plt
import numpy as np

from skimage.io import imread, imshow
from skimage.color import rgb2hsv
from skimage.exposure import histogram, cumulative_distribution
from skimage.filters import threshold_otsu

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install mediapipe
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 22.0 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision

# %%
sail= imread('/content/drive/MyDrive/IMV/Segmentasi/ashlyn.jpg')
imshow(sail)

# %%
th = 0.4
Sail_gray_bw = Sail_gray_bw<th
imshow(sail_gray_bw)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-592f67f5f763> in <cell line: 2>()
#       1 th = 0.4
# ----> 2 Sail_gray_bw = Sail_gray_bw<th
#       3 imshow(sail_gray_bw)
#
# NameError: name 'Sail_gray_bw' is not defined

# %%
image_test_subset = image_test[0:num_images]

# %%
directory_path_imagetest = '/content/drive/MyDrive/TUGAS SBC/Image Segmentation/dataset segmentasi/test/mandible/images/*.png'

images_test= [cv2.imread(img, 0) for img_test in image_test_subset]
images_test = []

image_files_test = os.listdir(directory_path_imagetest)
for image_files_test in image_files_test:
    image_path_test = os.path.join(directory_path_imagetest, image_files_test)
    img_test = Image.open(image_path_test)
    img_array_test = np.array(img_test)
    images_test.append(img_array_test)

images_test = []
image_files_test = os.listdir(directory_path_imagetest)

for image_files_test in image_files_test:
    image_path_test = os.path.join(directory_path_imagetest, image_files_test)
    img_test = Image.open(image_path_test)
    img_test = img_test.resize((3100, 1300))
    img_array_test = np.array(img_test)
    images_test.append(img_array_test)

image_dataset_test = np.array(images_test)

if len(image_dataset_test.shape) == 3:
    image_dataset_test = np.expand_dims(image_dataset_train, axis=3)

image_dataset_test= np.array(images_test)
image_dataset_test = np.expand_dims(image_dataset_test, axis = 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-fc9eaa6f9ffe> in <cell line: 3>()
#       1 directory_path_imagetest = '/content/drive/MyDrive/TUGAS SBC/Image Segmentation/dataset segmentasi/test/mandible/images/*.png'
#       2
# ----> 3 images_test= [cv2.imread(img, 0) for img_test in image_test_subset]
#       4 images_test = []
#       5
#
# <ipython-input-35-fc9eaa6f9ffe> in <listcomp>(.0)
#       1 directory_path_imagetest = '/content/drive/MyDrive/TUGAS SBC/Image Segmentation/dataset segmentasi/test/mandible/images/*.png'
#       2
# ----> 3 images_test= [cv2.imread(img, 0) for img_test in image_test_subset]
#       4 images_test = []
#       5
#
# NameError: name 'img' is not defined
